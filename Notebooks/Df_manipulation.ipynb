# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/Clear_Reefs.csv')

# %%
data
# Out:
#       Unnamed: 0.1  Unnamed: 0      Null  Clear Land     Cloud  Cloud Shadow  \
# 0                0           0  0.461118    0.000000  0.000000      0.000000
# 1                1           0  0.461118    0.000000  0.000000      0.000000
# 2                2           0  0.461118    0.000000  0.000000      0.000000
# 3                3           0  0.461118    0.000000  0.000000      0.217781
# 4                4           0  0.461118    0.000000  0.000000      0.000000
# ...            ...         ...       ...         ...       ...           ...
# 5592          5592           0  0.557731    0.000000  0.024350      0.029891
# 5593          5593           0  0.557731    0.000000  0.064259      0.045112
# 5594          5594           0  0.557731    0.000000  0.008403      0.011154
# 5595          5595           0  0.557731    0.000006  0.004445      0.003948
# 5596          5596           0  0.557731    0.000019  0.001691      0.004283
#
# ...

# %%
data.full_path = data.full_path.str.replace("/run", "")

# %%
data
# Out:
#       Unnamed: 0      Null  Clear Land     Cloud  Cloud Shadow      Snow  \
# 0              0  0.461118    0.000000  0.000000      0.000000  0.000000
# 1              0  0.461118    0.000000  0.000000      0.000000  0.000000
# 2              0  0.461118    0.000000  0.000000      0.000000  0.000000
# 3              0  0.461118    0.000000  0.000000      0.217781  0.000000
# 4              0  0.461118    0.000000  0.000000      0.000000  0.000000
# ...          ...       ...         ...       ...           ...       ...
# 5592           0  0.557731    0.000000  0.024350      0.029891  0.000000
# 5593           0  0.557731    0.000000  0.064259      0.045112  0.000000
# 5594           0  0.557731    0.000000  0.008403      0.011154  0.000000
# 5595           0  0.557731    0.000006  0.004445      0.003948  0.000038
# 5596           0  0.557731    0.000019  0.001691      0.004283  0.000003
#
#          Water                                                img  \
# ...

# %%
data.full_dir = data.full_dir.str.replace("/media", "")

# %%
data.to_csv('../Data/Clear_Reefs.csv')
